# %%
import keras
import tensorflow as tf
from keras import backend as K
import sys
import sklearn as sk
import pandas as pd
K.tensorflow_backend._get_available_gpus()
# Out:
# Using TensorFlow backend.
# []

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words = 10000)
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/reuters.npz
# 2113536/2110848 [==============================] - 5s 2us/step

# %%
len(train_data)
# Out:
# 8982

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in
train_data[0]])
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 1s 2us/step

# %%
#  transforma as sequencias de integers em vetores de 0s, com 1s onde a
#  palavra representada pelo integer está presente

import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
decoded_newswire
# Out:
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %%
#  transforma as labels em vetores de 0s, 
#  com 1s na posição onde a label é a correta

def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results

one_hot_train_labels = to_one_hot(train_labels)
one_hot_test_labels = to_one_hot(test_labels)

# %%
#  versão alternativa do codigo acima

from keras.utils.np_utils import to_categorical


one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
#  construindo a rede neural

from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
#separando valores de treinamento para validação

x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model.fit(partial_x_train,
                   partial_y_train,
                   epochs = 20,
                   batch_size = 512,
                   validation_data = (x_val, y_val))
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/20
# 7982/7982 [==============================] - 3s 321us/step - loss: 2.5322 - acc: 0.4955 - val_loss: 1.7207 - val_acc: 0.6130
# Epoch 2/20
# 7982/7982 [==============================] - 1s 156us/step - loss: 1.4452 - acc: 0.6879 - val_loss: 1.3455 - val_acc: 0.7060
# Epoch 3/20
# 7982/7982 [==============================] - 1s 154us/step - loss: 1.0951 - acc: 0.7651 - val_loss: 1.1710 - val_acc: 0.7430
# Epoch 4/20
# 7982/7982 [==============================] - 1s 152us/step - loss: 0.8696 - acc: 0.8158 - val_loss: 1.0790 - val_acc: 0.7590
# Epoch 5/20
# 7982/7982 [==============================] - 1s 154us/step - loss: 0.7031 - acc: 0.8473 - val_loss: 0.9847 - val_acc: 0.7840
# Epoch 6/20
# 7982/7982 [==============================] - 1s 155us/step - loss: 0.5662 - acc: 0.8796 - val_loss: 0.9417 - val_acc: 0.8030
# Epoch 7/20
# 7982/7982 [==============================] - 1s 153us/step - loss: 0.4580 - acc: 0.9053 - val_loss: 0.9079 - val_acc: 0.8010
# Epoch 8/20
# 7982/7982 [==============================] - 1s 160us/step - loss: 0.3693 - acc: 0.9228 - val_loss: 0.9361 - val_acc: 0.7880
# Epoch 9/20
# 7982/7982 [==============================] - 1s 153us/step - loss: 0.3032 - acc: 0.9307 - val_loss: 0.8919 - val_acc: 0.8090
# Epoch 10/20
# 7982/7982 [==============================] - 1s 156us/step - loss: 0.2538 - acc: 0.9416 - val_loss: 0.9079 - val_acc: 0.8110
# Epoch 11/20
# 7982/7982 [==============================] - 1s 164us/step - loss: 0.2186 - acc: 0.9468 - val_loss: 0.9183 - val_acc: 0.8130
# Epoch 12/20
# 7982/7982 [==============================] - 1s 156us/step - loss: 0.1873 - acc: 0.9506 - val_loss: 0.9055 - val_acc: 0.8130
# Epoch 13/20
# 7982/7982 [==============================] - 1s 154us/step - loss: 0.1700 - acc: 0.9528 - val_loss: 0.9343 - val_acc: 0.8090
# Epoch 14/20
# 7982/7982 [==============================] - 1s 155us/step - loss: 0.1535 - acc: 0.9558 - val_loss: 0.9718 - val_acc: 0.8060
# Epoch 15/20
# 7982/7982 [==============================] - 1s 157us/step - loss: 0.1392 - acc: 0.9555 - val_loss: 0.9706 - val_acc: 0.8140
# Epoch 16/20
# 7982/7982 [==============================] - 1s 171us/step - loss: 0.1313 - acc: 0.9562 - val_loss: 1.0234 - val_acc: 0.8070
# Epoch 17/20
# 7982/7982 [==============================] - 2s 225us/step - loss: 0.1215 - acc: 0.9579 - val_loss: 1.0262 - val_acc: 0.7960
# Epoch 18/20
# 7982/7982 [==============================] - 1s 185us/step - loss: 0.1200 - acc: 0.9578 - val_loss: 1.0437 - val_acc: 0.8070
# Epoch 19/20
# 7982/7982 [==============================] - 1s 154us/step - loss: 0.1138 - acc: 0.9593 - val_loss: 1.0969 - val_acc: 0.7980
# Epoch 20/20
# 7982/7982 [==============================] - 1s 158us/step - loss: 0.1110 - acc: 0.9594 - val_loss: 1.0681 - val_acc: 0.8010

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#  Second test with 9 epochs

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))
model.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])
model.fit(partial_x_train,
partial_y_train,
epochs=9,
batch_size=512,
validation_data=(x_val, y_val))
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 2s 220us/step - loss: 2.5353 - acc: 0.5244 - val_loss: 1.6782 - val_acc: 0.6550
# Epoch 2/9
# 7982/7982 [==============================] - 1s 160us/step - loss: 1.3682 - acc: 0.7136 - val_loss: 1.2725 - val_acc: 0.7230
# Epoch 3/9
# 7982/7982 [==============================] - 1s 155us/step - loss: 1.0101 - acc: 0.7808 - val_loss: 1.1310 - val_acc: 0.7500
# Epoch 4/9
# 7982/7982 [==============================] - 1s 155us/step - loss: 0.7957 - acc: 0.8254 - val_loss: 1.0530 - val_acc: 0.7590
# Epoch 5/9
# 7982/7982 [==============================] - 1s 155us/step - loss: 0.6387 - acc: 0.8631 - val_loss: 0.9733 - val_acc: 0.7950
# Epoch 6/9
# 7982/7982 [==============================] - 1s 157us/step - loss: 0.5116 - acc: 0.8926 - val_loss: 0.9090 - val_acc: 0.8100
# Epoch 7/9
# 7982/7982 [==============================] - 1s 156us/step - loss: 0.4122 - acc: 0.9141 - val_loss: 0.8934 - val_acc: 0.8220
# Epoch 8/9
# 7982/7982 [==============================] - 1s 166us/step - loss: 0.3356 - acc: 0.9288 - val_loss: 0.8716 - val_acc: 0.8250
# Epoch 9/9
# 7982/7982 [==============================] - 1s 154us/step - loss: 0.2783 - acc: 0.9372 - val_loss: 0.9344 - val_acc: 0.8020
# 2246/2246 [==============================] - 0s 176us/step

# %%
results
# Out:
# [1.0209990643223588, 0.7760463045944832]

# %%
#  faz previsoes baseado no modelo previamente criado

predictions = model.predict(x_test)

# %%
predictions
# Out:
# array([[1.08722852e-05, 8.21044378e-05, 2.80510230e-05, ...,
#         3.05624417e-05, 6.26427254e-06, 1.06249872e-05],
#        [8.21456255e-04, 1.98914986e-02, 3.50797805e-03, ...,
#         5.45123068e-04, 1.20208297e-05, 2.68297474e-04],
#        [1.47847214e-03, 7.76862085e-01, 2.34955293e-03, ...,
#         1.23514415e-04, 1.60757615e-03, 1.86804711e-04],
#        ...,
#        [1.24383387e-05, 2.14347921e-04, 4.20579745e-05, ...,
#         8.46888088e-06, 1.15071103e-04, 1.23877435e-05],
#        [1.15956983e-03, 1.16735727e-01, 3.44259921e-03, ...,
#         5.54948056e-04, 7.20801880e-04, 3.61736806e-04],
#        [8.43680231e-04, 5.46270430e-01, 2.02752324e-03, ...,
#         4.50686202e-05, 4.63673554e-04, 1.52382738e-04]], dtype=float32)

# %%
for prediction in predictions:
    print('the predicition is: ', np.where(prediction == max(prediction)) , ' -> ' , max(prediction))
# Out:
# the predicition is:  (array([3], dtype=int64),)  ->  0.97198975
# the predicition is:  (array([10], dtype=int64),)  ->  0.9155582
# the predicition is:  (array([1], dtype=int64),)  ->  0.7768621
# the predicition is:  (array([16], dtype=int64),)  ->  0.5069209
# the predicition is:  (array([13], dtype=int64),)  ->  0.943438
# the predicition is:  (array([3], dtype=int64),)  ->  0.9909202
# the predicition is:  (array([3], dtype=int64),)  ->  0.9979966
# the predicition is:  (array([3], dtype=int64),)  ->  0.99956554
# the predicition is:  (array([3], dtype=int64),)  ->  0.9995653
# the predicition is:  (array([3], dtype=int64),)  ->  0.94170314
# the predicition is:  (array([1], dtype=int64),)  ->  0.83640844
# the predicition is:  (array([4], dtype=int64),)  ->  0.9788092
# the predicition is:  (array([1], dtype=int64),)  ->  0.9946965
# the predicition is:  (array([3], dtype=int64),)  ->  0.996536
# the predicition is:  (array([1], dtype=int64),)  ->  0.8946131
# the predicition is:  (array([11], dtype=int64),)  ->  0.9996934
# the predicition is:  (array([3], dtype=int64),)  ->  0.38399798
# the predicition is:  (array([3], dtype=int64),)  ->  0.9919212
# the predicition is:  (array([19], dtype=int64),)  ->  0.9802183
# the predicition is:  (array([3], dtype=int64),)  ->  0.9986029
# the predicition is:  (array([8], dtype=int64),)  ->  0.8271025
# the predicition is:  (array([3], dtype=int64),)  ->  0.9846639
# the predicition is:  (array([3], dtype=int64),)  ->  0.9727606
# the predicition is:  (array([3], dtype=int64),)  ->  0.95117915
# the predicition is:  (array([9], dtype=int64),)  ->  0.76329166
# the predicition is:  (array([3], dtype=int64),)  ->  0.99498796
# the predicition is:  (array([4], dtype=int64),)  ->  0.9974056
# the predicition is:  (array([6], dtype=int64),)  ->  0.9544636
# the predicition is:  (array([10], dtype=int64),)  ->  0.7580249
# the predicition is:  (array([3], dtype=int64),)  ->  0.9882301
# the predicition is:  (array([3], dtype=int64),)  ->  0.9881821
# the predicition is:  (array([10], dtype=int64),)  ->  0.6537227
# the predicition is:  (array([16], dtype=int64),)  ->  0.8808516
# the predicition is:  (array([3], dtype=int64),)  ->  0.98799217
# the predicition is:  (array([19], dtype=int64),)  ->  0.8563545
# the predicition is:  (array([4], dtype=int64),)  ->  0.9909288
# the predicition is:  (array([19], dtype=int64),)  ->  0.21720776
# the predicition is:  (array([1], dtype=int64),)  ->  0.9690964
# the predicition is:  (array([4], dtype=int64),)  ->  0.9170721
# the predicition is:  (array([3], dtype=int64),)  ->  0.9853066
# the predicition is:  (array([3], dtype=int64),)  ->  0.65226287
# the predicition is:  (array([21], dtype=int64),)  ->  0.67538625
# the predicition is:  (array([3], dtype=int64),)  ->  0.9736867
# the predicition is:  (array([34], dtype=int64),)  ->  0.53545094
# the predicition is:  (array([4], dtype=int64),)  ->  0.9947443
# the predicition is:  (array([4], dtype=int64),)  ->  0.999995
# the predicition is:  (array([3], dtype=int64),)  ->  0.9991099
# the predicition is:  (array([4], dtype=int64),)  ->  0.998379
# the predicition is:  (array([3], dtype=int64),)  ->  0.97507906
# the predicition is:  (array([11], dtype=int64),)  ->  0.44605473
# the predicition is:  (array([20], dtype=int64),)  ->  0.7760878
# the predicition is:  (array([3], dtype=int64),)  ->  0.99251187
# the predicition is:  (array([3], dtype=int64),)  ->  0.9994516
# the predicition is:  (array([3], dtype=int64),)  ->  0.99561936
# the predicition is:  (array([3], dtype=int64),)  ->  0.97454697
# the predicition is:  (array([19], dtype=int64),)  ->  0.42664045
# the predicition is:  (array([26], dtype=int64),)  ->  0.26171225
# the predicition is:  (array([4], dtype=int64),)  ->  0.8009523
# the predicition is:  (array([20], dtype=int64),)  ->  0.38026056
# the predicition is:  (array([19], dtype=int64),)  ->  0.995363
# the predicition is:  (array([3], dtype=int64),)  ->  0.63587976
# the predicition is:  (array([3], dtype=int64),)  ->  0.99484164
# the predicition is:  (array([4], dtype=int64),)  ->  0.83458513
# the predicition is:  (array([4], dtype=int64),)  ->  0.98599225
# the predicition is:  (array([4], dtype=int64),)  ->  0.9454711
# the predicition is:  (array([3], dtype=int64),)  ->  0.992572
# the predicition is:  (array([3], dtype=int64),)  ->  0.9995943
# the predicition is:  (array([1], dtype=int64),)  ->  0.9752239
# the predicition is:  (array([3], dtype=int64),)  ->  0.9678624
# the predicition is:  (array([4], dtype=int64),)  ->  0.999998
# the predicition is:  (array([19], dtype=int64),)  ->  0.45096615
# the predicition is:  (array([16], dtype=int64),)  ->  0.42783436
# the predicition is:  (array([3], dtype=int64),)  ->  0.9046907
# the predicition is:  (array([19], dtype=int64),)  ->  0.9981304
# the predicition is:  (array([43], dtype=int64),)  ->  0.7857515
# the predicition is:  (array([24], dtype=int64),)  ->  0.52478886
# the predicition is:  (array([1], dtype=int64),)  ->  0.7144661
# the predicition is:  (array([3], dtype=int64),)  ->  0.9771947
# the predicition is:  (array([3], dtype=int64),)  ->  0.12457162
# the predicition is:  (array([4], dtype=int64),)  ->  0.99858993
# the predicition is:  (array([3], dtype=int64),)  ->  0.99313676
# the predicition is:  (array([3], dtype=int64),)  ->  0.9745769
# the predicition is:  (array([3], dtype=int64),)  ->  0.9824101
# the predicition is:  (array([11], dtype=int64),)  ->  0.34809345
# the predicition is:  (array([3], dtype=int64),)  ->  0.3594966
# the predicition is:  (array([20], dtype=int64),)  ->  0.9096448
# the predicition is:  (array([1], dtype=int64),)  ->  0.2862119
# the predicition is:  (array([16], dtype=int64),)  ->  0.22066823
# the predicition is:  (array([4], dtype=int64),)  ->  0.7229748
# the predicition is:  (array([3], dtype=int64),)  ->  0.9994272
# the predicition is:  (array([3], dtype=int64),)  ->  0.9769778
# the predicition is:  (array([4], dtype=int64),)  ->  0.9866305
# the predicition is:  (array([3], dtype=int64),)  ->  0.99402976
# the predicition is:  (array([19], dtype=int64),)  ->  0.60719365
# the predicition is:  (array([3], dtype=int64),)  ->  0.9841232
# the predicition is:  (array([16], dtype=int64),)  ->  0.55492616
# the predicition is:  (array([11], dtype=int64),)  ->  0.7742819
# the predicition is:  (array([3], dtype=int64),)  ->  0.98625726
# the predicition is:  (array([4], dtype=int64),)  ->  0.9705585
# the predicition is:  (array([1], dtype=int64),)  ->  0.3215887
# the predicition is:  (array([41], dtype=int64),)  ->  0.945912
# the predicition is:  (array([3], dtype=int64),)  ->  0.9046907
# the predicition is:  (array([20], dtype=int64),)  ->  0.6395533
# the predicition is:  (array([3], dtype=int64),)  ->  0.99917185
# the predicition is:  (array([3], dtype=int64),)  ->  0.9918046
# the predicition is:  (array([3], dtype=int64),)  ->  0.7404683
# the predicition is:  (array([4], dtype=int64),)  ->  0.9924522
# the predicition is:  (array([13], dtype=int64),)  ->  0.8550137
# the predicition is:  (array([4], dtype=int64),)  ->  0.9998093
# the predicition is:  (array([3], dtype=int64),)  ->  0.904787
# the predicition is:  (array([19], dtype=int64),)  ->  0.99165076
# the predicition is:  (array([3], dtype=int64),)  ->  0.9989191
# the predicition is:  (array([4], dtype=int64),)  ->  0.4889213
# the predicition is:  (array([3], dtype=int64),)  ->  0.91692954
# the predicition is:  (array([16], dtype=int64),)  ->  0.2870589
# the predicition is:  (array([3], dtype=int64),)  ->  0.99783045
# the predicition is:  (array([4], dtype=int64),)  ->  0.83716804
# the predicition is:  (array([4], dtype=int64),)  ->  0.98212737
# the predicition is:  (array([3], dtype=int64),)  ->  0.9853806
# the predicition is:  (array([4], dtype=int64),)  ->  0.98243195
# the predicition is:  (array([3], dtype=int64),)  ->  0.9800633
# the predicition is:  (array([3], dtype=int64),)  ->  0.46211335
# the predicition is:  (array([19], dtype=int64),)  ->  0.958485
# the predicition is:  (array([4], dtype=int64),)  ->  0.95035684
# the predicition is:  (array([18], dtype=int64),)  ->  0.5988868
# the predicition is:  (array([3], dtype=int64),)  ->  0.9446747
# the predicition is:  (array([19], dtype=int64),)  ->  0.9256972
# the predicition is:  (array([3], dtype=int64),)  ->  0.99088705
# the predicition is:  (array([4], dtype=int64),)  ->  0.8222515
# the predicition is:  (array([3], dtype=int64),)  ->  0.98237807
# the predicition is:  (array([8], dtype=int64),)  ->  0.9208365
# the predicition is:  (array([3], dtype=int64),)  ->  0.9840829
# the predicition is:  (array([1], dtype=int64),)  ->  0.8150782
# the predicition is:  (array([3], dtype=int64),)  ->  0.9998584
# the predicition is:  (array([3], dtype=int64),)  ->  0.54553854
# the predicition is:  (array([4], dtype=int64),)  ->  0.95580584
# the predicition is:  (array([13], dtype=int64),)  ->  0.9660236
# the predicition is:  (array([1], dtype=int64),)  ->  0.9474476
# the predicition is:  (array([3], dtype=int64),)  ->  0.99739766
# the predicition is:  (array([3], dtype=int64),)  ->  0.9931162
# the predicition is:  (array([3], dtype=int64),)  ->  0.9297333
# the predicition is:  (array([3], dtype=int64),)  ->  0.99818355
# the predicition is:  (array([4], dtype=int64),)  ->  0.9996166
# the predicition is:  (array([4], dtype=int64),)  ->  0.9751285
# the predicition is:  (array([20], dtype=int64),)  ->  0.78594553
# the predicition is:  (array([1], dtype=int64),)  ->  0.74360824
# the predicition is:  (array([4], dtype=int64),)  ->  0.89430034
# the predicition is:  (array([6], dtype=int64),)  ->  0.1829932
# the predicition is:  (array([3], dtype=int64),)  ->  0.97612566
# the predicition is:  (array([3], dtype=int64),)  ->  0.9999919
# the predicition is:  (array([3], dtype=int64),)  ->  0.38605732
# the predicition is:  (array([4], dtype=int64),)  ->  0.9987388
# the predicition is:  (array([3], dtype=int64),)  ->  0.99205434
# the predicition is:  (array([3], dtype=int64),)  ->  0.9799684
# the predicition is:  (array([4], dtype=int64),)  ->  0.5336568
# the predicition is:  (array([1], dtype=int64),)  ->  0.9399641
# the predicition is:  (array([3], dtype=int64),)  ->  0.99656856
# the predicition is:  (array([3], dtype=int64),)  ->  0.9465405
# the predicition is:  (array([11], dtype=int64),)  ->  0.9999044
# the predicition is:  (array([17], dtype=int64),)  ->  0.7955277
# the predicition is:  (array([3], dtype=int64),)  ->  0.9745063
# the predicition is:  (array([3], dtype=int64),)  ->  0.5762234
# the predicition is:  (array([2], dtype=int64),)  ->  0.32427844
# the predicition is:  (array([4], dtype=int64),)  ->  0.99494404
# the predicition is:  (array([3], dtype=int64),)  ->  0.9928289
# the predicition is:  (array([4], dtype=int64),)  ->  0.99979323
# the predicition is:  (array([3], dtype=int64),)  ->  0.9999355
# the predicition is:  (array([1], dtype=int64),)  ->  0.5145335
# the predicition is:  (array([3], dtype=int64),)  ->  0.9635473
# the predicition is:  (array([3], dtype=int64),)  ->  0.99929917
# the predicition is:  (array([3], dtype=int64),)  ->  0.9976381
# the predicition is:  (array([3], dtype=int64),)  ->  0.58808136
# the predicition is:  (array([3], dtype=int64),)  ->  0.98285174
# the predicition is:  (array([3], dtype=int64),)  ->  0.43928957
# the predicition is:  (array([3], dtype=int64),)  ->  0.9711166
# the predicition is:  (array([21], dtype=int64),)  ->  0.9110133
# the predicition is:  (array([4], dtype=int64),)  ->  0.862159
# the predicition is:  (array([16], dtype=int64),)  ->  0.38992
# the predicition is:  (array([3], dtype=int64),)  ->  0.98295504
# the predicition is:  (array([3], dtype=int64),)  ->  0.84245783
# the predicition is:  (array([3], dtype=int64),)  ->  0.9984669
# the predicition is:  (array([8], dtype=int64),)  ->  0.56779224
# the predicition is:  (array([3], dtype=int64),)  ->  0.9878613
# the predicition is:  (array([20], dtype=int64),)  ->  0.5478385
# the predicition is:  (array([3], dtype=int64),)  ->  0.9997104
# the predicition is:  (array([21], dtype=int64),)  ->  0.75017375
# the predicition is:  (array([3], dtype=int64),)  ->  0.98838717
# the predicition is:  (array([3], dtype=int64),)  ->  0.9348331
# the predicition is:  (array([6], dtype=int64),)  ->  0.9537732
# the predicition is:  (array([21], dtype=int64),)  ->  0.33962694
# the predicition is:  (array([8], dtype=int64),)  ->  0.770894
# the predicition is:  (array([3], dtype=int64),)  ->  0.9681989
# the predicition is:  (array([11], dtype=int64),)  ->  0.7949146
# the predicition is:  (array([36], dtype=int64),)  ->  0.38734117
# the predicition is:  (array([8], dtype=int64),)  ->  0.9402243
# the predicition is:  (array([1], dtype=int64),)  ->  0.76285636
# the predicition is:  (array([3], dtype=int64),)  ->  0.8899493
# the predicition is:  (array([4], dtype=int64),)  ->  0.9873051
# the predicition is:  (array([19], dtype=int64),)  ->  0.5114712
# the predicition is:  (array([4], dtype=int64),)  ->  0.6201767
# the predicition is:  (array([16], dtype=int64),)  ->  0.9919823
# the predicition is:  (array([19], dtype=int64),)  ->  0.58888346
# the predicition is:  (array([19], dtype=int64),)  ->  0.9780085
# the predicition is:  (array([3], dtype=int64),)  ->  0.5659617
# the predicition is:  (array([3], dtype=int64),)  ->  0.9996032
# the predicition is:  (array([4], dtype=int64),)  ->  0.514889
# the predicition is:  (array([4], dtype=int64),)  ->  0.44223556
# the predicition is:  (array([19], dtype=int64),)  ->  0.95436025
# the predicition is:  (array([3], dtype=int64),)  ->  0.096161075
# the predicition is:  (array([4], dtype=int64),)  ->  0.7504642
# the predicition is:  (array([3], dtype=int64),)  ->  0.9609657
# the predicition is:  (array([4], dtype=int64),)  ->  0.9972487
# the predicition is:  (array([3], dtype=int64),)  ->  0.9691469
# the predicition is:  (array([3], dtype=int64),)  ->  0.99127394
# the predicition is:  (array([3], dtype=int64),)  ->  0.9648363
# the predicition is:  (array([20], dtype=int64),)  ->  0.7028309
# the predicition is:  (array([4], dtype=int64),)  ->  0.9261667
# the predicition is:  (array([21], dtype=int64),)  ->  0.29996657
# the predicition is:  (array([3], dtype=int64),)  ->  0.96295375
# the predicition is:  (array([3], dtype=int64),)  ->  0.99944144
# the predicition is:  (array([3], dtype=int64),)  ->  0.9933849
# the predicition is:  (array([3], dtype=int64),)  ->  0.94828653
# the predicition is:  (array([3], dtype=int64),)  ->  0.9873871
# the predicition is:  (array([4], dtype=int64),)  ->  0.8472065
# the predicition is:  (array([13], dtype=int64),)  ->  0.8915777
# the predicition is:  (array([3], dtype=int64),)  ->  0.9905951
# the predicition is:  (array([13], dtype=int64),)  ->  0.22308566
# the predicition is:  (array([16], dtype=int64),)  ->  0.4868651
# the predicition is:  (array([25], dtype=int64),)  ->  0.6226844
# the predicition is:  (array([3], dtype=int64),)  ->  0.996899
# the predicition is:  (array([4], dtype=int64),)  ->  0.9825174
# the predicition is:  (array([19], dtype=int64),)  ->  0.58738565
# the predicition is:  (array([3], dtype=int64),)  ->  0.99917537
# the predicition is:  (array([11], dtype=int64),)  ->  0.9810433
# the predicition is:  (array([9], dtype=int64),)  ->  0.97803533
# the predicition is:  (array([1], dtype=int64),)  ->  0.6380502
# the predicition is:  (array([3], dtype=int64),)  ->  0.8995856
# the predicition is:  (array([3], dtype=int64),)  ->  0.99271363
# the predicition is:  (array([11], dtype=int64),)  ->  0.2968407
# the predicition is:  (array([1], dtype=int64),)  ->  0.6290385
# the predicition is:  (array([19], dtype=int64),)  ->  0.9773702
# the predicition is:  (array([1], dtype=int64),)  ->  0.7988682
# the predicition is:  (array([4], dtype=int64),)  ->  0.9858995
# the predicition is:  (array([4], dtype=int64),)  ->  0.90374887
# the predicition is:  (array([11], dtype=int64),)  ->  0.7875823
# the predicition is:  (array([3], dtype=int64),)  ->  0.9908468
# the predicition is:  (array([3], dtype=int64),)  ->  0.9357967
# the predicition is:  (array([4], dtype=int64),)  ->  0.9995907
# the predicition is:  (array([19], dtype=int64),)  ->  0.5309861
# the predicition is:  (array([3], dtype=int64),)  ->  0.9999552
# the predicition is:  (array([4], dtype=int64),)  ->  0.994578
# the predicition is:  (array([4], dtype=int64),)  ->  0.9280761
# the predicition is:  (array([3], dtype=int64),)  ->  0.9971591
# the predicition is:  (array([3], dtype=int64),)  ->  0.9860415
# the predicition is:  (array([25], dtype=int64),)  ->  0.8897578
# the predicition is:  (array([4], dtype=int64),)  ->  0.99828964
# the predicition is:  (array([31], dtype=int64),)  ->  0.7520181
# the predicition is:  (array([4], dtype=int64),)  ->  0.8910796
# the predicition is:  (array([26], dtype=int64),)  ->  0.26006618
# the predicition is:  (array([11], dtype=int64),)  ->  0.7828091
# the predicition is:  (array([19], dtype=int64),)  ->  0.9579576
# the predicition is:  (array([4], dtype=int64),)  ->  0.8938993
# the predicition is:  (array([4], dtype=int64),)  ->  0.92924875
# the predicition is:  (array([4], dtype=int64),)  ->  0.93079704
# the predicition is:  (array([21], dtype=int64),)  ->  0.5477993
# the predicition is:  (array([3], dtype=int64),)  ->  0.993034
# the predicition is:  (array([4], dtype=int64),)  ->  0.925644
# the predicition is:  (array([4], dtype=int64),)  ->  0.740001
# the predicition is:  (array([3], dtype=int64),)  ->  0.99506015
# the predicition is:  (array([10], dtype=int64),)  ->  0.57862973
# the predicition is:  (array([19], dtype=int64),)  ->  0.58304244
# the predicition is:  (array([19], dtype=int64),)  ->  0.9933849
# the predicition is:  (array([3], dtype=int64),)  ->  0.996802
# the predicition is:  (array([3], dtype=int64),)  ->  0.9926918
# the predicition is:  (array([20], dtype=int64),)  ->  0.7774855
# the predicition is:  (array([3], dtype=int64),)  ->  0.9779729
# the predicition is:  (array([4], dtype=int64),)  ->  0.59015757
# the predicition is:  (array([19], dtype=int64),)  ->  0.9378273
# the predicition is:  (array([16], dtype=int64),)  ->  0.93618596
# the predicition is:  (array([3], dtype=int64),)  ->  0.9980709
# the predicition is:  (array([3], dtype=int64),)  ->  0.76312757
# the predicition is:  (array([4], dtype=int64),)  ->  0.9951121
# the predicition is:  (array([16], dtype=int64),)  ->  0.99932766
# the predicition is:  (array([4], dtype=int64),)  ->  0.8038543
# the predicition is:  (array([3], dtype=int64),)  ->  0.999811
# the predicition is:  (array([3], dtype=int64),)  ->  0.9597288
# the predicition is:  (array([3], dtype=int64),)  ->  0.97291505
# the predicition is:  (array([3], dtype=int64),)  ->  0.99909496
# the predicition is:  (array([4], dtype=int64),)  ->  0.9515199
# the predicition is:  (array([1], dtype=int64),)  ->  0.13629526
# the predicition is:  (array([3], dtype=int64),)  ->  0.8797406
# the predicition is:  (array([3], dtype=int64),)  ->  0.50064826
# the predicition is:  (array([19], dtype=int64),)  ->  0.3525834
# the predicition is:  (array([3], dtype=int64),)  ->  0.97466564
# the predicition is:  (array([4], dtype=int64),)  ->  0.87408096
# the predicition is:  (array([16], dtype=int64),)  ->  0.81513965
# the predicition is:  (array([4], dtype=int64),)  ->  0.981991
# the predicition is:  (array([4], dtype=int64),)  ->  0.9942924
# the predicition is:  (array([16], dtype=int64),)  ->  0.98656857
# the predicition is:  (array([16], dtype=int64),)  ->  0.98460335
# the predicition is:  (array([3], dtype=int64),)  ->  0.9985746
# the predicition is:  (array([11], dtype=int64),)  ->  0.37922847
# the predicition is:  (array([3], dtype=int64),)  ->  0.97713065
# the predicition is:  (array([19], dtype=int64),)  ->  0.9758985
# the predicition is:  (array([36], dtype=int64),)  ->  0.34672874
# the predicition is:  (array([3], dtype=int64),)  ->  0.9995553
# the predicition is:  (array([6], dtype=int64),)  ->  0.5255636
# the predicition is:  (array([3], dtype=int64),)  ->  0.9872751
# the predicition is:  (array([16], dtype=int64),)  ->  0.9690179
# the predicition is:  (array([3], dtype=int64),)  ->  0.9963199
# the predicition is:  (array([16], dtype=int64),)  ->  0.56748
# the predicition is:  (array([21], dtype=int64),)  ->  0.36952075
# the predicition is:  (array([4], dtype=int64),)  ->  0.99995506
# the predicition is:  (array([3], dtype=int64),)  ->  0.9729022
# the predicition is:  (array([4], dtype=int64),)  ->  0.9014538
# the predicition is:  (array([1], dtype=int64),)  ->  0.7767775
# the predicition is:  (array([16], dtype=int64),)  ->  0.8851446
# the predicition is:  (array([3], dtype=int64),)  ->  0.6382141
# the predicition is:  (array([2], dtype=int64),)  ->  0.8703276
# the predicition is:  (array([3], dtype=int64),)  ->  0.9984634
# the predicition is:  (array([21], dtype=int64),)  ->  0.19085811
# the predicition is:  (array([3], dtype=int64),)  ->  0.95758253
# the predicition is:  (array([25], dtype=int64),)  ->  0.47657034
# the predicition is:  (array([8], dtype=int64),)  ->  0.685139
# the predicition is:  (array([3], dtype=int64),)  ->  0.94183975
# the predicition is:  (array([3], dtype=int64),)  ->  0.9819228
# the predicition is:  (array([11], dtype=int64),)  ->  0.3996766
# the predicition is:  (array([3], dtype=int64),)  ->  0.97083515
# the predicition is:  (array([19], dtype=int64),)  ->  0.9660007
# the predicition is:  (array([4], dtype=int64),)  ->  0.9295318
# the predicition is:  (array([19], dtype=int64),)  ->  0.9849952
# the predicition is:  (array([3], dtype=int64),)  ->  0.9995993
# the predicition is:  (array([4], dtype=int64),)  ->  0.7379874
# the predicition is:  (array([3], dtype=int64),)  ->  0.9929086
# the predicition is:  (array([3], dtype=int64),)  ->  0.99228436
# the predicition is:  (array([21], dtype=int64),)  ->  0.38887307
# the predicition is:  (array([16], dtype=int64),)  ->  0.93618596
# the predicition is:  (array([19], dtype=int64),)  ->  0.898428
# the predicition is:  (array([26], dtype=int64),)  ->  0.1294813
# the predicition is:  (array([3], dtype=int64),)  ->  0.9937323
# the predicition is:  (array([19], dtype=int64),)  ->  0.98751616
# the predicition is:  (array([16], dtype=int64),)  ->  0.3392987
# the predicition is:  (array([3], dtype=int64),)  ->  0.99300236
# the predicition is:  (array([3], dtype=int64),)  ->  0.9994553
# the predicition is:  (array([16], dtype=int64),)  ->  0.61813635
# the predicition is:  (array([3], dtype=int64),)  ->  0.97306246
# the predicition is:  (array([3], dtype=int64),)  ->  0.46771228
# the predicition is:  (array([3], dtype=int64),)  ->  0.9900337
# the predicition is:  (array([16], dtype=int64),)  ->  0.6703043
# the predicition is:  (array([4], dtype=int64),)  ->  0.8666146
# the predicition is:  (array([4], dtype=int64),)  ->  0.8739963
# the predicition is:  (array([3], dtype=int64),)  ->  0.9684645
# the predicition is:  (array([3], dtype=int64),)  ->  0.98627
# the predicition is:  (array([3], dtype=int64),)  ->  0.97315377
# the predicition is:  (array([19], dtype=int64),)  ->  0.87742
# the predicition is:  (array([43], dtype=int64),)  ->  0.24856207
# the predicition is:  (array([3], dtype=int64),)  ->  0.9877648
# the predicition is:  (array([9], dtype=int64),)  ->  0.9670283
# the predicition is:  (array([3], dtype=int64),)  ->  0.99995863
# the predicition is:  (array([4], dtype=int64),)  ->  0.9544768
# the predicition is:  (array([4], dtype=int64),)  ->  0.7709744
# the predicition is:  (array([10], dtype=int64),)  ->  0.80661213
# the predicition is:  (array([4], dtype=int64),)  ->  0.74473965
# the predicition is:  (array([21], dtype=int64),)  ->  0.6874856
# the predicition is:  (array([3], dtype=int64),)  ->  0.99325705
# the predicition is:  (array([3], dtype=int64),)  ->  0.9806137
# the predicition is:  (array([13], dtype=int64),)  ->  0.7635054
# the predicition is:  (array([3], dtype=int64),)  ->  0.9314877
# the predicition is:  (array([3], dtype=int64),)  ->  0.9118547
# the predicition is:  (array([1], dtype=int64),)  ->  0.32972845
# the predicition is:  (array([11], dtype=int64),)  ->  0.99809235
# the predicition is:  (array([1], dtype=int64),)  ->  0.57300305
# the predicition is:  (array([4], dtype=int64),)  ->  0.8915989
# the predicition is:  (array([1], dtype=int64),)  ->  0.8475251
# the predicition is:  (array([11], dtype=int64),)  ->  0.57957536
# the predicition is:  (array([3], dtype=int64),)  ->  0.99972767
# the predicition is:  (array([38], dtype=int64),)  ->  0.16809408
# the predicition is:  (array([3], dtype=int64),)  ->  0.99935097
# the predicition is:  (array([3], dtype=int64),)  ->  0.9982444
# the predicition is:  (array([3], dtype=int64),)  ->  0.9787973
# the predicition is:  (array([10], dtype=int64),)  ->  0.62667984
# the predicition is:  (array([20], dtype=int64),)  ->  0.63774157
# the predicition is:  (array([3], dtype=int64),)  ->  0.99998355
# the predicition is:  (array([16], dtype=int64),)  ->  0.76821923
# the predicition is:  (array([11], dtype=int64),)  ->  0.5799084
# the predicition is:  (array([19], dtype=int64),)  ->  0.67910045
# the predicition is:  (array([6], dtype=int64),)  ->  0.3127525
# the predicition is:  (array([3], dtype=int64),)  ->  0.98365223
# the predicition is:  (array([3], dtype=int64),)  ->  0.17381002
# the predicition is:  (array([16], dtype=int64),)  ->  0.76059586
# the predicition is:  (array([3], dtype=int64),)  ->  0.98422897
# the predicition is:  (array([44], dtype=int64),)  ->  0.5655436
# the predicition is:  (array([16], dtype=int64),)  ->  0.9982331
# the predicition is:  (array([3], dtype=int64),)  ->  0.99721766
# the predicition is:  (array([4], dtype=int64),)  ->  0.56706244
# the predicition is:  (array([3], dtype=int64),)  ->  0.9108595
# the predicition is:  (array([3], dtype=int64),)  ->  0.8735234
# the predicition is:  (array([16], dtype=int64),)  ->  0.9784889
# the predicition is:  (array([4], dtype=int64),)  ->  0.41861227
# the predicition is:  (array([19], dtype=int64),)  ->  0.9500827
# the predicition is:  (array([4], dtype=int64),)  ->  0.99344105
# the predicition is:  (array([11], dtype=int64),)  ->  0.94190145
# the predicition is:  (array([9], dtype=int64),)  ->  0.36975467
# the predicition is:  (array([3], dtype=int64),)  ->  0.9997049
# the predicition is:  (array([19], dtype=int64),)  ->  0.9322
# the predicition is:  (array([3], dtype=int64),)  ->  0.21316515
# the predicition is:  (array([3], dtype=int64),)  ->  0.98735374
# the predicition is:  (array([3], dtype=int64),)  ->  0.9850433
# the predicition is:  (array([1], dtype=int64),)  ->  0.9682889
# the predicition is:  (array([3], dtype=int64),)  ->  0.9992643
# the predicition is:  (array([3], dtype=int64),)  ->  0.9931629
# the predicition is:  (array([4], dtype=int64),)  ->  0.92890173
# the predicition is:  (array([4], dtype=int64),)  ->  0.4704866
# the predicition is:  (array([3], dtype=int64),)  ->  0.99972194
# the predicition is:  (array([3], dtype=int64),)  ->  0.94802266
# the predicition is:  (array([4], dtype=int64),)  ->  0.97620165
# the predicition is:  (array([3], dtype=int64),)  ->  0.94139606
# the predicition is:  (array([4], dtype=int64),)  ->  0.9949096
# the predicition is:  (array([1], dtype=int64),)  ->  0.4754914
# the predicition is:  (array([4], dtype=int64),)  ->  0.9872859
# the predicition is:  (array([3], dtype=int64),)  ->  0.9438553
# the predicition is:  (array([1], dtype=int64),)  ->  0.26728418
# the predicition is:  (array([1], dtype=int64),)  ->  0.5111687
# the predicition is:  (array([4], dtype=int64),)  ->  0.9999988
# the predicition is:  (array([3], dtype=int64),)  ->  0.9709637
# the predicition is:  (array([3], dtype=int64),)  ->  0.4797848
# the predicition is:  (array([4], dtype=int64),)  ->  0.22636132
# the predicition is:  (array([11], dtype=int64),)  ->  0.46315205
# the predicition is:  (array([3], dtype=int64),)  ->  0.99963164
# the predicition is:  (array([36], dtype=int64),)  ->  0.7532914
# the predicition is:  (array([1], dtype=int64),)  ->  0.32530513
# the predicition is:  (array([3], dtype=int64),)  ->  0.99558735
# the predicition is:  (array([3], dtype=int64),)  ->  0.99551105
# the predicition is:  (array([3], dtype=int64),)  ->  0.99373925
# the predicition is:  (array([3], dtype=int64),)  ->  0.9853609
# the predicition is:  (array([9], dtype=int64),)  ->  0.5298711
# the predicition is:  (array([4], dtype=int64),)  ->  0.9300113
# the predicition is:  (array([1], dtype=int64),)  ->  0.7306041
# the predicition is:  (array([19], dtype=int64),)  ->  0.99923635
# the predicition is:  (array([19], dtype=int64),)  ->  0.33788794
# the predicition is:  (array([32], dtype=int64),)  ->  0.37538093
# the predicition is:  (array([3], dtype=int64),)  ->  0.90099376
# the predicition is:  (array([4], dtype=int64),)  ->  0.43126625
# the predicition is:  (array([3], dtype=int64),)  ->  0.98831904
# the predicition is:  (array([4], dtype=int64),)  ->  0.9928266
# the predicition is:  (array([8], dtype=int64),)  ->  0.7595241
# the predicition is:  (array([21], dtype=int64),)  ->  0.8147312
# the predicition is:  (array([1], dtype=int64),)  ->  0.97293776
# the predicition is:  (array([3], dtype=int64),)  ->  0.9682827
# the predicition is:  (array([8], dtype=int64),)  ->  0.3800046
# the predicition is:  (array([19], dtype=int64),)  ->  0.992504
# the predicition is:  (array([19], dtype=int64),)  ->  0.8291112
# the predicition is:  (array([34], dtype=int64),)  ->  0.26609188
# the predicition is:  (array([3], dtype=int64),)  ->  0.9618914
# the predicition is:  (array([4], dtype=int64),)  ->  0.99201185
# the predicition is:  (array([3], dtype=int64),)  ->  0.9835302
# the predicition is:  (array([3], dtype=int64),)  ->  0.9827979
# the predicition is:  (array([3], dtype=int64),)  ->  0.5329347
# the predicition is:  (array([25], dtype=int64),)  ->  0.22873744
# the predicition is:  (array([11], dtype=int64),)  ->  0.30304295
# the predicition is:  (array([4], dtype=int64),)  ->  0.5756706
# the predicition is:  (array([4], dtype=int64),)  ->  0.976551
# the predicition is:  (array([20], dtype=int64),)  ->  0.85185796
# the predicition is:  (array([3], dtype=int64),)  ->  0.9969144
# the predicition is:  (array([4], dtype=int64),)  ->  0.99991465
# the predicition is:  (array([4], dtype=int64),)  ->  0.99780995
# the predicition is:  (array([3], dtype=int64),)  ->  0.8784635
# the predicition is:  (array([13], dtype=int64),)  ->  0.90773284
# the predicition is:  (array([4], dtype=int64),)  ->  0.98831826
# the predicition is:  (array([3], dtype=int64),)  ->  0.9875306
# the predicition is:  (array([19], dtype=int64),)  ->  0.99609023
# the predicition is:  (array([4], dtype=int64),)  ->  0.91092813
# the predicition is:  (array([4], dtype=int64),)  ->  0.96324414
# the predicition is:  (array([3], dtype=int64),)  ->  0.9857371
# the predicition is:  (array([8], dtype=int64),)  ->  0.77014303
# the predicition is:  (array([11], dtype=int64),)  ->  0.24294433
# the predicition is:  (array([4], dtype=int64),)  ->  0.69689447
# the predicition is:  (array([3], dtype=int64),)  ->  0.99981636
# the predicition is:  (array([4], dtype=int64),)  ->  0.7174771
# the predicition is:  (array([3], dtype=int64),)  ->  0.9919693
# the predicition is:  (array([3], dtype=int64),)  ->  0.99970895
# the predicition is:  (array([3], dtype=int64),)  ->  0.9808445
# the predicition is:  (array([16], dtype=int64),)  ->  0.9981438
# the predicition is:  (array([4], dtype=int64),)  ->  0.6712123
# the predicition is:  (array([11], dtype=int64),)  ->  0.8936609
# the predicition is:  (array([3], dtype=int64),)  ->  0.98295134
# the predicition is:  (array([11], dtype=int64),)  ->  0.24983159
# the predicition is:  (array([19], dtype=int64),)  ->  0.5483315
# the predicition is:  (array([4], dtype=int64),)  ->  0.7944321
# the predicition is:  (array([3], dtype=int64),)  ->  0.95593995
# the predicition is:  (array([3], dtype=int64),)  ->  0.9985409
# the predicition is:  (array([3], dtype=int64),)  ->  0.9970866
# the predicition is:  (array([3], dtype=int64),)  ->  0.9857701
# the predicition is:  (array([3], dtype=int64),)  ->  0.9711166
# the predicition is:  (array([4], dtype=int64),)  ->  0.98135537
# the predicition is:  (array([3], dtype=int64),)  ->  0.7611343
# the predicition is:  (array([6], dtype=int64),)  ->  0.8976044
# the predicition is:  (array([3], dtype=int64),)  ->  0.998669
# the predicition is:  (array([4], dtype=int64),)  ->  0.9270006
# the predicition is:  (array([3], dtype=int64),)  ->  0.9814958
# the predicition is:  (array([3], dtype=int64),)  ->  0.9991566
# the predicition is:  (array([3], dtype=int64),)  ->  0.98977906
# the predicition is:  (array([4], dtype=int64),)  ->  0.89252096
# the predicition is:  (array([1], dtype=int64),)  ->  0.9028136
# the predicition is:  (array([4], dtype=int64),)  ->  0.99674714
# the predicition is:  (array([4], dtype=int64),)  ->  0.94055736
# the predicition is:  (array([3], dtype=int64),)  ->  0.95109946
# the predicition is:  (array([4], dtype=int64),)  ->  0.8820478
# the predicition is:  (array([4], dtype=int64),)  ->  0.706916
# the predicition is:  (array([3], dtype=int64),)  ->  0.99165726
# the predicition is:  (array([3], dtype=int64),)  ->  0.98682064
# the predicition is:  (array([1], dtype=int64),)  ->  0.97007126
# the predicition is:  (array([19], dtype=int64),)  ->  0.9991985
# the predicition is:  (array([4], dtype=int64),)  ->  0.2560071
# the predicition is:  (array([1], dtype=int64),)  ->  0.27954674
# the predicition is:  (array([4], dtype=int64),)  ->  0.7490097
# the predicition is:  (array([9], dtype=int64),)  ->  0.61271334
# the predicition is:  (array([1], dtype=int64),)  ->  0.9894443
# the predicition is:  (array([3], dtype=int64),)  ->  0.9880581
# the predicition is:  (array([11], dtype=int64),)  ->  0.96960795
# the predicition is:  (array([3], dtype=int64),)  ->  0.9782056
# the predicition is:  (array([3], dtype=int64),)  ->  0.9312731
# the predicition is:  (array([4], dtype=int64),)  ->  0.9926158
# the predicition is:  (array([21], dtype=int64),)  ->  0.7997507
# the predicition is:  (array([4], dtype=int64),)  ->  0.8898096
# the predicition is:  (array([3], dtype=int64),)  ->  0.99477696
# the predicition is:  (array([19], dtype=int64),)  ->  0.5200622
# the predicition is:  (array([13], dtype=int64),)  ->  0.9069896
# the predicition is:  (array([3], dtype=int64),)  ->  0.13761802
# the predicition is:  (array([44], dtype=int64),)  ->  0.5301101
# the predicition is:  (array([4], dtype=int64),)  ->  0.85169345
# the predicition is:  (array([13], dtype=int64),)  ->  0.47116777
# the predicition is:  (array([3], dtype=int64),)  ->  0.43007657
# the predicition is:  (array([20], dtype=int64),)  ->  0.3062157
# the predicition is:  (array([4], dtype=int64),)  ->  0.8044207
# the predicition is:  (array([4], dtype=int64),)  ->  0.99712014
# the predicition is:  (array([3], dtype=int64),)  ->  0.9709656
# the predicition is:  (array([11], dtype=int64),)  ->  0.9211343
# the predicition is:  (array([3], dtype=int64),)  ->  0.3455217
# the predicition is:  (array([16], dtype=int64),)  ->  0.45079002
# the predicition is:  (array([2], dtype=int64),)  ->  0.57454795
# the predicition is:  (array([24], dtype=int64),)  ->  0.70223284
# the predicition is:  (array([3], dtype=int64),)  ->  0.98661846
# the predicition is:  (array([3], dtype=int64),)  ->  0.26581135
# the predicition is:  (array([4], dtype=int64),)  ->  0.97023535
# the predicition is:  (array([21], dtype=int64),)  ->  0.6129934
# the predicition is:  (array([31], dtype=int64),)  ->  0.28500387
# the predicition is:  (array([4], dtype=int64),)  ->  0.49796754
# the predicition is:  (array([34], dtype=int64),)  ->  0.44503132
# the predicition is:  (array([3], dtype=int64),)  ->  0.99844366
# the predicition is:  (array([4], dtype=int64),)  ->  0.9466458
# the predicition is:  (array([3], dtype=int64),)  ->  0.9831072
# the predicition is:  (array([16], dtype=int64),)  ->  0.98018163
# the predicition is:  (array([3], dtype=int64),)  ->  0.39332837
# the predicition is:  (array([10], dtype=int64),)  ->  0.33453795
# the predicition is:  (array([3], dtype=int64),)  ->  0.95782024
# the predicition is:  (array([3], dtype=int64),)  ->  0.9575588
# the predicition is:  (array([11], dtype=int64),)  ->  0.37622577
# the predicition is:  (array([3], dtype=int64),)  ->  0.999666
# the predicition is:  (array([3], dtype=int64),)  ->  0.76861465
# the predicition is:  (array([3], dtype=int64),)  ->  0.9956987
# the predicition is:  (array([20], dtype=int64),)  ->  0.40035295
# the predicition is:  (array([3], dtype=int64),)  ->  0.98411906
# the predicition is:  (array([3], dtype=int64),)  ->  0.98038864
# the predicition is:  (array([4], dtype=int64),)  ->  0.7460577
# the predicition is:  (array([11], dtype=int64),)  ->  0.5119663
# the predicition is:  (array([3], dtype=int64),)  ->  0.96815443
# the predicition is:  (array([4], dtype=int64),)  ->  0.8962116
# the predicition is:  (array([4], dtype=int64),)  ->  0.9885561
# the predicition is:  (array([8], dtype=int64),)  ->  0.901906
# the predicition is:  (array([3], dtype=int64),)  ->  0.9710065
# the predicition is:  (array([16], dtype=int64),)  ->  0.9999752
# the predicition is:  (array([16], dtype=int64),)  ->  0.72483224
# the predicition is:  (array([3], dtype=int64),)  ->  0.9831445
# the predicition is:  (array([4], dtype=int64),)  ->  0.75395507
# the predicition is:  (array([3], dtype=int64),)  ->  0.2732827
# the predicition is:  (array([4], dtype=int64),)  ->  0.9904665
# the predicition is:  (array([11], dtype=int64),)  ->  0.3609261
# the predicition is:  (array([3], dtype=int64),)  ->  0.9770732
# the predicition is:  (array([3], dtype=int64),)  ->  0.9925458
# the predicition is:  (array([3], dtype=int64),)  ->  0.93553674
# the predicition is:  (array([16], dtype=int64),)  ->  0.53812397
# the predicition is:  (array([3], dtype=int64),)  ->  0.9901264
# the predicition is:  (array([3], dtype=int64),)  ->  0.9979272
# the predicition is:  (array([16], dtype=int64),)  ->  0.9957753
# the predicition is:  (array([4], dtype=int64),)  ->  0.7990432
# the predicition is:  (array([25], dtype=int64),)  ->  0.86931336
# the predicition is:  (array([11], dtype=int64),)  ->  0.72312415
# the predicition is:  (array([4], dtype=int64),)  ->  0.9907918
# the predicition is:  (array([1], dtype=int64),)  ->  0.7194308
# the predicition is:  (array([4], dtype=int64),)  ->  0.9991295
# the predicition is:  (array([3], dtype=int64),)  ->  0.6003036
# the predicition is:  (array([3], dtype=int64),)  ->  0.6750273
# the predicition is:  (array([3], dtype=int64),)  ->  0.97673357
# the predicition is:  (array([19], dtype=int64),)  ->  0.66592145
# the predicition is:  (array([3], dtype=int64),)  ->  0.68644285
# the predicition is:  (array([3], dtype=int64),)  ->  0.9739861
# the predicition is:  (array([16], dtype=int64),)  ->  0.9994431
# the predicition is:  (array([3], dtype=int64),)  ->  0.8852917
# the predicition is:  (array([36], dtype=int64),)  ->  0.6749984
# the predicition is:  (array([3], dtype=int64),)  ->  0.9957034
# the predicition is:  (array([18], dtype=int64),)  ->  0.45590177
# the predicition is:  (array([3], dtype=int64),)  ->  0.96615076
# the predicition is:  (array([3], dtype=int64),)  ->  0.987433
# the predicition is:  (array([4], dtype=int64),)  ->  0.99871504
# the predicition is:  (array([19], dtype=int64),)  ->  0.28079602
# the predicition is:  (array([4], dtype=int64),)  ->  0.7370405
# the predicition is:  (array([3], dtype=int64),)  ->  0.8834389
# the predicition is:  (array([4], dtype=int64),)  ->  0.4825001
# the predicition is:  (array([11], dtype=int64),)  ->  0.99845433
# the predicition is:  (array([19], dtype=int64),)  ->  0.43602777
# the predicition is:  (array([20], dtype=int64),)  ->  0.6648275
# the predicition is:  (array([12], dtype=int64),)  ->  0.20598467
# the predicition is:  (array([4], dtype=int64),)  ->  0.8870494
# the predicition is:  (array([3], dtype=int64),)  ->  0.97626513
# the predicition is:  (array([3], dtype=int64),)  ->  0.9831308
# the predicition is:  (array([3], dtype=int64),)  ->  0.9884504
# the predicition is:  (array([16], dtype=int64),)  ->  0.99553275
# the predicition is:  (array([0], dtype=int64),)  ->  0.56505746
# the predicition is:  (array([1], dtype=int64),)  ->  0.9845558
# the predicition is:  (array([4], dtype=int64),)  ->  0.9988212
# the predicition is:  (array([3], dtype=int64),)  ->  0.9919308
# the predicition is:  (array([3], dtype=int64),)  ->  0.9489616
# the predicition is:  (array([1], dtype=int64),)  ->  0.74291986
# the predicition is:  (array([16], dtype=int64),)  ->  0.23026659
# the predicition is:  (array([3], dtype=int64),)  ->  0.99990785
# the predicition is:  (array([19], dtype=int64),)  ->  0.99132526
# the predicition is:  (array([36], dtype=int64),)  ->  0.34521955
# the predicition is:  (array([3], dtype=int64),)  ->  0.96738875
# the predicition is:  (array([11], dtype=int64),)  ->  0.99584097
# the predicition is:  (array([4], dtype=int64),)  ->  0.9778656
# the predicition is:  (array([3], dtype=int64),)  ->  0.99284315
# the predicition is:  (array([16], dtype=int64),)  ->  0.9988894
# the predicition is:  (array([3], dtype=int64),)  ->  0.98338544
# the predicition is:  (array([3], dtype=int64),)  ->  0.98709804
# the predicition is:  (array([19], dtype=int64),)  ->  0.18809031
# the predicition is:  (array([4], dtype=int64),)  ->  0.9678257
# the predicition is:  (array([8], dtype=int64),)  ->  0.8651868
# the predicition is:  (array([19], dtype=int64),)  ->  0.74309105
# the predicition is:  (array([3], dtype=int64),)  ->  0.9989262
# the predicition is:  (array([3], dtype=int64),)  ->  0.97962177
# the predicition is:  (array([3], dtype=int64),)  ->  0.07771786
# the predicition is:  (array([3], dtype=int64),)  ->  0.98254114
# the predicition is:  (array([3], dtype=int64),)  ->  0.98260975
# the predicition is:  (array([3], dtype=int64),)  ->  0.9963117
# the predicition is:  (array([13], dtype=int64),)  ->  0.98424834
# the predicition is:  (array([18], dtype=int64),)  ->  0.62517893
# the predicition is:  (array([3], dtype=int64),)  ->  0.9843501
# the predicition is:  (array([19], dtype=int64),)  ->  0.99831736
# the predicition is:  (array([1], dtype=int64),)  ->  0.9822119
# the predicition is:  (array([16], dtype=int64),)  ->  0.9624553
# the predicition is:  (array([4], dtype=int64),)  ->  0.9542282
# the predicition is:  (array([3], dtype=int64),)  ->  0.99867153
# the predicition is:  (array([3], dtype=int64),)  ->  0.98512495
# the predicition is:  (array([4], dtype=int64),)  ->  0.9253141
# the predicition is:  (array([3], dtype=int64),)  ->  0.95577884
# the predicition is:  (array([16], dtype=int64),)  ->  0.9851217
# the predicition is:  (array([4], dtype=int64),)  ->  0.1741602
# the predicition is:  (array([4], dtype=int64),)  ->  0.9677221
# the predicition is:  (array([2], dtype=int64),)  ->  0.14817448
# the predicition is:  (array([4], dtype=int64),)  ->  0.8888131
# the predicition is:  (array([19], dtype=int64),)  ->  0.95098096
# the predicition is:  (array([3], dtype=int64),)  ->  0.9978599
# the predicition is:  (array([19], dtype=int64),)  ->  0.27497935
# the predicition is:  (array([8], dtype=int64),)  ->  0.2997033
# the predicition is:  (array([3], dtype=int64),)  ->  0.9719059
# the predicition is:  (array([3], dtype=int64),)  ->  0.9690036
# the predicition is:  (array([4], dtype=int64),)  ->  0.9671162
# the predicition is:  (array([3], dtype=int64),)  ->  0.3557675
# the predicition is:  (array([3], dtype=int64),)  ->  0.98757356
# the predicition is:  (array([4], dtype=int64),)  ->  0.96304566
# the predicition is:  (array([4], dtype=int64),)  ->  0.8246679
# the predicition is:  (array([3], dtype=int64),)  ->  0.9935209
# the predicition is:  (array([4], dtype=int64),)  ->  0.9445302
# the predicition is:  (array([3], dtype=int64),)  ->  0.99844664
# the predicition is:  (array([3], dtype=int64),)  ->  0.7821816
# the predicition is:  (array([11], dtype=int64),)  ->  0.25286716
# the predicition is:  (array([1], dtype=int64),)  ->  0.7555111
# the predicition is:  (array([8], dtype=int64),)  ->  0.13613506
# the predicition is:  (array([3], dtype=int64),)  ->  0.99419326
# the predicition is:  (array([4], dtype=int64),)  ->  0.47072744
# the predicition is:  (array([16], dtype=int64),)  ->  0.6190928
# the predicition is:  (array([3], dtype=int64),)  ->  0.9824667
# the predicition is:  (array([16], dtype=int64),)  ->  0.9994615
# the predicition is:  (array([3], dtype=int64),)  ->  0.9598033
# the predicition is:  (array([3], dtype=int64),)  ->  0.9823925
# the predicition is:  (array([3], dtype=int64),)  ->  0.9994265
# the predicition is:  (array([1], dtype=int64),)  ->  0.50701237
# the predicition is:  (array([3], dtype=int64),)  ->  0.9543699
# the predicition is:  (array([19], dtype=int64),)  ->  0.99820614
# the predicition is:  (array([20], dtype=int64),)  ->  0.7387508
# the predicition is:  (array([4], dtype=int64),)  ->  0.9373558
# the predicition is:  (array([1], dtype=int64),)  ->  0.50027996
# the predicition is:  (array([3], dtype=int64),)  ->  0.9877872
# the predicition is:  (array([3], dtype=int64),)  ->  0.9582405
# the predicition is:  (array([20], dtype=int64),)  ->  0.9927925
# the predicition is:  (array([11], dtype=int64),)  ->  0.21928185
# the predicition is:  (array([11], dtype=int64),)  ->  0.9687482
# the predicition is:  (array([1], dtype=int64),)  ->  0.9204125
# the predicition is:  (array([4], dtype=int64),)  ->  0.9929836
# the predicition is:  (array([19], dtype=int64),)  ->  0.8418664
# the predicition is:  (array([1], dtype=int64),)  ->  0.19142576
# the predicition is:  (array([13], dtype=int64),)  ->  0.99607074
# the predicition is:  (array([4], dtype=int64),)  ->  0.9885717
# the predicition is:  (array([3], dtype=int64),)  ->  0.99856865
# the predicition is:  (array([25], dtype=int64),)  ->  0.43234107
# the predicition is:  (array([3], dtype=int64),)  ->  0.76146936
# the predicition is:  (array([19], dtype=int64),)  ->  0.8387991
# the predicition is:  (array([3], dtype=int64),)  ->  0.995845
# the predicition is:  (array([21], dtype=int64),)  ->  0.8927073
# the predicition is:  (array([25], dtype=int64),)  ->  0.18511413
# the predicition is:  (array([3], dtype=int64),)  ->  0.99616337
# the predicition is:  (array([3], dtype=int64),)  ->  0.99907434
# the predicition is:  (array([1], dtype=int64),)  ->  0.8294306
# the predicition is:  (array([8], dtype=int64),)  ->  0.7464689
# the predicition is:  (array([3], dtype=int64),)  ->  0.9364809
# the predicition is:  (array([3], dtype=int64),)  ->  0.99842083
# the predicition is:  (array([12], dtype=int64),)  ->  0.98239374
# the predicition is:  (array([3], dtype=int64),)  ->  0.9949897
# the predicition is:  (array([19], dtype=int64),)  ->  0.360786
# the predicition is:  (array([4], dtype=int64),)  ->  0.9108617
# the predicition is:  (array([19], dtype=int64),)  ->  0.6051565
# the predicition is:  (array([4], dtype=int64),)  ->  0.65106547
# the predicition is:  (array([4], dtype=int64),)  ->  0.97182447
# the predicition is:  (array([4], dtype=int64),)  ->  0.99273586
# the predicition is:  (array([19], dtype=int64),)  ->  0.6078093
# the predicition is:  (array([3], dtype=int64),)  ->  0.9663343
# the predicition is:  (array([25], dtype=int64),)  ->  0.22287253
# the predicition is:  (array([3], dtype=int64),)  ->  0.99917287
# the predicition is:  (array([19], dtype=int64),)  ->  0.9262245
# the predicition is:  (array([3], dtype=int64),)  ->  0.9424013
# the predicition is:  (array([30], dtype=int64),)  ->  0.11497287
# the predicition is:  (array([3], dtype=int64),)  ->  0.9984458
# the predicition is:  (array([16], dtype=int64),)  ->  0.45824093
# the predicition is:  (array([3], dtype=int64),)  ->  0.9908982
# the predicition is:  (array([3], dtype=int64),)  ->  0.9715229
# the predicition is:  (array([11], dtype=int64),)  ->  0.9837352
# the predicition is:  (array([3], dtype=int64),)  ->  0.9609919
# the predicition is:  (array([4], dtype=int64),)  ->  0.886203
# the predicition is:  (array([3], dtype=int64),)  ->  0.99531317
# the predicition is:  (array([4], dtype=int64),)  ->  0.9957982
# the predicition is:  (array([11], dtype=int64),)  ->  0.37366822
# the predicition is:  (array([3], dtype=int64),)  ->  0.9821337
# the predicition is:  (array([0], dtype=int64),)  ->  0.9495136
# the predicition is:  (array([42], dtype=int64),)  ->  0.425186
# the predicition is:  (array([3], dtype=int64),)  ->  0.98229676
# the predicition is:  (array([4], dtype=int64),)  ->  0.9523582
# the predicition is:  (array([3], dtype=int64),)  ->  0.9291365
# the predicition is:  (array([16], dtype=int64),)  ->  0.46403918
# the predicition is:  (array([3], dtype=int64),)  ->  0.97949284
# the predicition is:  (array([4], dtype=int64),)  ->  0.9528812
# the predicition is:  (array([3], dtype=int64),)  ->  0.9955439
# the predicition is:  (array([3], dtype=int64),)  ->  0.98919
# the predicition is:  (array([4], dtype=int64),)  ->  0.550138
# ...
# the predicition is:  (array([4], dtype=int64),)  ->  0.9974571
# the predicition is:  (array([3], dtype=int64),)  ->  0.910223
# the predicition is:  (array([4], dtype=int64),)  ->  0.9773088
# the predicition is:  (array([4], dtype=int64),)  ->  0.71141815
# the predicition is:  (array([19], dtype=int64),)  ->  0.9716833
# the predicition is:  (array([4], dtype=int64),)  ->  0.9124917
# the predicition is:  (array([36], dtype=int64),)  ->  0.893878
# the predicition is:  (array([3], dtype=int64),)  ->  0.9988959
# the predicition is:  (array([11], dtype=int64),)  ->  0.85615516
# the predicition is:  (array([4], dtype=int64),)  ->  0.9999038
# the predicition is:  (array([23], dtype=int64),)  ->  0.7577962
# the predicition is:  (array([8], dtype=int64),)  ->  0.7249946
# the predicition is:  (array([3], dtype=int64),)  ->  0.916122
# the predicition is:  (array([4], dtype=int64),)  ->  0.9170792
# the predicition is:  (array([3], dtype=int64),)  ->  0.98890185
# the predicition is:  (array([1], dtype=int64),)  ->  0.6685398
# the predicition is:  (array([20], dtype=int64),)  ->  0.90525943
# the predicition is:  (array([2], dtype=int64),)  ->  0.23182388
# the predicition is:  (array([3], dtype=int64),)  ->  0.9593616
# the predicition is:  (array([4], dtype=int64),)  ->  0.4926257
# the predicition is:  (array([25], dtype=int64),)  ->  0.4499405
# the predicition is:  (array([19], dtype=int64),)  ->  0.9465722
# the predicition is:  (array([4], dtype=int64),)  ->  0.987867
# the predicition is:  (array([16], dtype=int64),)  ->  0.8262737
# the predicition is:  (array([3], dtype=int64),)  ->  0.18030955
# the predicition is:  (array([3], dtype=int64),)  ->  0.9996295
# the predicition is:  (array([3], dtype=int64),)  ->  0.985873
# the predicition is:  (array([4], dtype=int64),)  ->  0.9539181
# the predicition is:  (array([3], dtype=int64),)  ->  0.9983695
# the predicition is:  (array([11], dtype=int64),)  ->  0.74201554
# the predicition is:  (array([3], dtype=int64),)  ->  0.96892256
# the predicition is:  (array([16], dtype=int64),)  ->  0.2607124
# the predicition is:  (array([3], dtype=int64),)  ->  0.99449015
# the predicition is:  (array([19], dtype=int64),)  ->  0.9860534
# the predicition is:  (array([3], dtype=int64),)  ->  0.9984364
# the predicition is:  (array([3], dtype=int64),)  ->  0.9907933
# the predicition is:  (array([19], dtype=int64),)  ->  0.8789571
# the predicition is:  (array([13], dtype=int64),)  ->  0.42033488
# the predicition is:  (array([3], dtype=int64),)  ->  0.99645895
# the predicition is:  (array([16], dtype=int64),)  ->  0.9894448
# the predicition is:  (array([3], dtype=int64),)  ->  0.96713424
# the predicition is:  (array([3], dtype=int64),)  ->  0.9782637
# the predicition is:  (array([36], dtype=int64),)  ->  0.59304136
# the predicition is:  (array([3], dtype=int64),)  ->  0.9968436
# the predicition is:  (array([3], dtype=int64),)  ->  0.6061414
# the predicition is:  (array([10], dtype=int64),)  ->  0.56558233
# the predicition is:  (array([1], dtype=int64),)  ->  0.7102731
# the predicition is:  (array([16], dtype=int64),)  ->  0.71324676
# the predicition is:  (array([23], dtype=int64),)  ->  0.7069555
# the predicition is:  (array([16], dtype=int64),)  ->  0.99544585
# the predicition is:  (array([1], dtype=int64),)  ->  0.65358627
# the predicition is:  (array([37], dtype=int64),)  ->  0.20253813
# the predicition is:  (array([19], dtype=int64),)  ->  0.9781275
# the predicition is:  (array([4], dtype=int64),)  ->  0.75202376
# the predicition is:  (array([4], dtype=int64),)  ->  0.95204777
# the predicition is:  (array([3], dtype=int64),)  ->  0.9957366
# the predicition is:  (array([3], dtype=int64),)  ->  0.98520803
# the predicition is:  (array([3], dtype=int64),)  ->  0.98193043
# the predicition is:  (array([19], dtype=int64),)  ->  0.30812994
# the predicition is:  (array([20], dtype=int64),)  ->  0.58725685
# the predicition is:  (array([4], dtype=int64),)  ->  0.95805514
# the predicition is:  (array([3], dtype=int64),)  ->  0.99911493
# the predicition is:  (array([19], dtype=int64),)  ->  0.87822384
# the predicition is:  (array([3], dtype=int64),)  ->  0.9474234
# the predicition is:  (array([8], dtype=int64),)  ->  0.55688375
# the predicition is:  (array([24], dtype=int64),)  ->  0.5387882
# the predicition is:  (array([3], dtype=int64),)  ->  0.92536014
# the predicition is:  (array([3], dtype=int64),)  ->  0.8399841
# the predicition is:  (array([3], dtype=int64),)  ->  0.2822072
# the predicition is:  (array([20], dtype=int64),)  ->  0.7186536
# the predicition is:  (array([18], dtype=int64),)  ->  0.18315217
# the predicition is:  (array([4], dtype=int64),)  ->  0.45982698
# the predicition is:  (array([1], dtype=int64),)  ->  0.20883456
# the predicition is:  (array([43], dtype=int64),)  ->  0.22789389
# the predicition is:  (array([3], dtype=int64),)  ->  0.97687817
# the predicition is:  (array([3], dtype=int64),)  ->  0.9964978
# the predicition is:  (array([3], dtype=int64),)  ->  0.9377263
# the predicition is:  (array([16], dtype=int64),)  ->  0.99860495
# the predicition is:  (array([19], dtype=int64),)  ->  0.96290326
# the predicition is:  (array([1], dtype=int64),)  ->  0.9175442
# the predicition is:  (array([3], dtype=int64),)  ->  0.9998031
# the predicition is:  (array([4], dtype=int64),)  ->  0.88609046
# the predicition is:  (array([4], dtype=int64),)  ->  0.9262577
# the predicition is:  (array([3], dtype=int64),)  ->  0.9949102
# the predicition is:  (array([4], dtype=int64),)  ->  0.96554494
# the predicition is:  (array([23], dtype=int64),)  ->  0.2820636
# the predicition is:  (array([3], dtype=int64),)  ->  0.999246
# the predicition is:  (array([4], dtype=int64),)  ->  0.8796254
# the predicition is:  (array([1], dtype=int64),)  ->  0.7906291
# the predicition is:  (array([21], dtype=int64),)  ->  0.58547133
# the predicition is:  (array([3], dtype=int64),)  ->  0.9170693
# the predicition is:  (array([1], dtype=int64),)  ->  0.098482065
# the predicition is:  (array([3], dtype=int64),)  ->  0.9995283
# the predicition is:  (array([16], dtype=int64),)  ->  0.36745405
# the predicition is:  (array([3], dtype=int64),)  ->  0.9852233
# the predicition is:  (array([1], dtype=int64),)  ->  0.16388622
# the predicition is:  (array([18], dtype=int64),)  ->  0.87309676
# the predicition is:  (array([3], dtype=int64),)  ->  0.99658513
# the predicition is:  (array([3], dtype=int64),)  ->  0.9331141
# the predicition is:  (array([3], dtype=int64),)  ->  0.9787732
# the predicition is:  (array([8], dtype=int64),)  ->  0.33558658
# the predicition is:  (array([4], dtype=int64),)  ->  0.9474218
# the predicition is:  (array([3], dtype=int64),)  ->  0.98643017
# the predicition is:  (array([4], dtype=int64),)  ->  0.9099487
# the predicition is:  (array([1], dtype=int64),)  ->  0.62109995
# the predicition is:  (array([3], dtype=int64),)  ->  0.9959973
# the predicition is:  (array([3], dtype=int64),)  ->  0.99560744
# the predicition is:  (array([3], dtype=int64),)  ->  0.9866014
# the predicition is:  (array([3], dtype=int64),)  ->  0.9957028
# the predicition is:  (array([18], dtype=int64),)  ->  0.36017746
# the predicition is:  (array([4], dtype=int64),)  ->  0.998667
# the predicition is:  (array([3], dtype=int64),)  ->  0.9856617
# the predicition is:  (array([3], dtype=int64),)  ->  0.9995208
# the predicition is:  (array([4], dtype=int64),)  ->  0.9058556
# the predicition is:  (array([4], dtype=int64),)  ->  0.92960966
# the predicition is:  (array([3], dtype=int64),)  ->  0.9920953
# the predicition is:  (array([4], dtype=int64),)  ->  0.9965346
# the predicition is:  (array([19], dtype=int64),)  ->  0.62370694
# the predicition is:  (array([4], dtype=int64),)  ->  0.5774261
# the predicition is:  (array([3], dtype=int64),)  ->  0.98224777
# the predicition is:  (array([3], dtype=int64),)  ->  0.9601388
# the predicition is:  (array([3], dtype=int64),)  ->  0.9800918
# the predicition is:  (array([3], dtype=int64),)  ->  0.96890223
# the predicition is:  (array([16], dtype=int64),)  ->  0.21245274
# the predicition is:  (array([11], dtype=int64),)  ->  0.99695766
# the predicition is:  (array([16], dtype=int64),)  ->  0.868718
# the predicition is:  (array([3], dtype=int64),)  ->  0.98460025
# the predicition is:  (array([3], dtype=int64),)  ->  0.45897922
# the predicition is:  (array([4], dtype=int64),)  ->  0.8895073
# the predicition is:  (array([16], dtype=int64),)  ->  0.9791616
# the predicition is:  (array([6], dtype=int64),)  ->  0.5266585
# the predicition is:  (array([18], dtype=int64),)  ->  0.5968226
# the predicition is:  (array([3], dtype=int64),)  ->  0.9475819
# the predicition is:  (array([4], dtype=int64),)  ->  0.98884857
# the predicition is:  (array([3], dtype=int64),)  ->  0.99342585
# the predicition is:  (array([4], dtype=int64),)  ->  0.99966276
# the predicition is:  (array([3], dtype=int64),)  ->  0.7333403
# the predicition is:  (array([10], dtype=int64),)  ->  0.56349856
# the predicition is:  (array([20], dtype=int64),)  ->  0.88671297
# the predicition is:  (array([3], dtype=int64),)  ->  0.99166334
# the predicition is:  (array([3], dtype=int64),)  ->  0.9925801
# the predicition is:  (array([11], dtype=int64),)  ->  0.99346775
# the predicition is:  (array([11], dtype=int64),)  ->  0.9578919
# the predicition is:  (array([21], dtype=int64),)  ->  0.7483446
# the predicition is:  (array([3], dtype=int64),)  ->  0.41162142
# the predicition is:  (array([4], dtype=int64),)  ->  0.41861227
# the predicition is:  (array([3], dtype=int64),)  ->  0.99068224
# the predicition is:  (array([3], dtype=int64),)  ->  0.6757117
# the predicition is:  (array([16], dtype=int64),)  ->  0.9217726
# the predicition is:  (array([1], dtype=int64),)  ->  0.36155143
# the predicition is:  (array([3], dtype=int64),)  ->  0.97017944
# the predicition is:  (array([3], dtype=int64),)  ->  0.99165666
# the predicition is:  (array([3], dtype=int64),)  ->  0.9866288
# the predicition is:  (array([3], dtype=int64),)  ->  0.9403284
# the predicition is:  (array([0], dtype=int64),)  ->  0.5449956
# the predicition is:  (array([11], dtype=int64),)  ->  0.99995005
# the predicition is:  (array([1], dtype=int64),)  ->  0.9769694
# the predicition is:  (array([36], dtype=int64),)  ->  0.81737065
# the predicition is:  (array([3], dtype=int64),)  ->  0.945047
# the predicition is:  (array([3], dtype=int64),)  ->  0.99517316
# the predicition is:  (array([3], dtype=int64),)  ->  0.9880195
# the predicition is:  (array([3], dtype=int64),)  ->  0.4341966
# the predicition is:  (array([4], dtype=int64),)  ->  0.98012483
# the predicition is:  (array([4], dtype=int64),)  ->  0.9944661
# the predicition is:  (array([3], dtype=int64),)  ->  0.9584828
# the predicition is:  (array([19], dtype=int64),)  ->  0.4162839
# the predicition is:  (array([1], dtype=int64),)  ->  0.9816176
# the predicition is:  (array([3], dtype=int64),)  ->  0.9961826
# the predicition is:  (array([20], dtype=int64),)  ->  0.52649426
# the predicition is:  (array([3], dtype=int64),)  ->  0.99721247
# the predicition is:  (array([11], dtype=int64),)  ->  0.7954169
# the predicition is:  (array([19], dtype=int64),)  ->  0.6922152
# the predicition is:  (array([16], dtype=int64),)  ->  0.7459336
# the predicition is:  (array([3], dtype=int64),)  ->  0.96635437
# the predicition is:  (array([19], dtype=int64),)  ->  0.59094346
# the predicition is:  (array([3], dtype=int64),)  ->  0.99419
# the predicition is:  (array([11], dtype=int64),)  ->  0.75972736
# the predicition is:  (array([20], dtype=int64),)  ->  0.9473023
# the predicition is:  (array([3], dtype=int64),)  ->  0.9454952
# the predicition is:  (array([31], dtype=int64),)  ->  0.34803447
# the predicition is:  (array([11], dtype=int64),)  ->  0.88914245
# the predicition is:  (array([20], dtype=int64),)  ->  0.9485802
# the predicition is:  (array([12], dtype=int64),)  ->  0.9286853
# the predicition is:  (array([4], dtype=int64),)  ->  0.9500123
# the predicition is:  (array([3], dtype=int64),)  ->  0.98302346
# the predicition is:  (array([3], dtype=int64),)  ->  0.99145144
# the predicition is:  (array([3], dtype=int64),)  ->  0.9895075
# the predicition is:  (array([3], dtype=int64),)  ->  0.78397405
# the predicition is:  (array([4], dtype=int64),)  ->  0.9156866
# the predicition is:  (array([20], dtype=int64),)  ->  0.63023597
# the predicition is:  (array([19], dtype=int64),)  ->  0.798499
# the predicition is:  (array([3], dtype=int64),)  ->  0.50412303
# the predicition is:  (array([4], dtype=int64),)  ->  0.98949254
# the predicition is:  (array([4], dtype=int64),)  ->  0.85553956
# the predicition is:  (array([1], dtype=int64),)  ->  0.9909436
# the predicition is:  (array([3], dtype=int64),)  ->  0.9971468
# the predicition is:  (array([3], dtype=int64),)  ->  0.7394455
# the predicition is:  (array([3], dtype=int64),)  ->  0.9921131
# the predicition is:  (array([3], dtype=int64),)  ->  0.99800605
# the predicition is:  (array([29], dtype=int64),)  ->  0.22215317
# the predicition is:  (array([3], dtype=int64),)  ->  0.36043698
# the predicition is:  (array([4], dtype=int64),)  ->  0.5230495
# the predicition is:  (array([11], dtype=int64),)  ->  0.18431903
# the predicition is:  (array([3], dtype=int64),)  ->  0.99274194
# the predicition is:  (array([11], dtype=int64),)  ->  0.98920035
# the predicition is:  (array([4], dtype=int64),)  ->  0.9733228
# the predicition is:  (array([3], dtype=int64),)  ->  0.9804514
# the predicition is:  (array([3], dtype=int64),)  ->  0.99395305
# the predicition is:  (array([3], dtype=int64),)  ->  0.9170693
# the predicition is:  (array([4], dtype=int64),)  ->  0.98944014
# the predicition is:  (array([4], dtype=int64),)  ->  0.98597425
# the predicition is:  (array([3], dtype=int64),)  ->  0.9954336
# the predicition is:  (array([3], dtype=int64),)  ->  0.9657128
# the predicition is:  (array([13], dtype=int64),)  ->  0.9990331
# the predicition is:  (array([18], dtype=int64),)  ->  0.10388204
# the predicition is:  (array([4], dtype=int64),)  ->  0.9880078
# the predicition is:  (array([3], dtype=int64),)  ->  0.99712616
# the predicition is:  (array([3], dtype=int64),)  ->  0.6863328
# the predicition is:  (array([19], dtype=int64),)  ->  0.2736488
# the predicition is:  (array([3], dtype=int64),)  ->  0.9553713
# the predicition is:  (array([8], dtype=int64),)  ->  0.89116526
# the predicition is:  (array([3], dtype=int64),)  ->  0.9845872
# the predicition is:  (array([10], dtype=int64),)  ->  0.556223
# the predicition is:  (array([16], dtype=int64),)  ->  0.25052434
# the predicition is:  (array([3], dtype=int64),)  ->  0.18030955
# the predicition is:  (array([11], dtype=int64),)  ->  0.502056
# the predicition is:  (array([16], dtype=int64),)  ->  0.87933356
# the predicition is:  (array([8], dtype=int64),)  ->  0.5763718
# the predicition is:  (array([11], dtype=int64),)  ->  0.1425193
# the predicition is:  (array([3], dtype=int64),)  ->  0.9749433
# the predicition is:  (array([3], dtype=int64),)  ->  0.986647
# the predicition is:  (array([4], dtype=int64),)  ->  0.99795353
# the predicition is:  (array([3], dtype=int64),)  ->  0.3687709
# the predicition is:  (array([3], dtype=int64),)  ->  0.9304885
# the predicition is:  (array([13], dtype=int64),)  ->  0.66593045
# the predicition is:  (array([3], dtype=int64),)  ->  0.9618828
# the predicition is:  (array([3], dtype=int64),)  ->  0.9838074
# the predicition is:  (array([3], dtype=int64),)  ->  0.8661467
# the predicition is:  (array([34], dtype=int64),)  ->  0.44821975
# the predicition is:  (array([18], dtype=int64),)  ->  0.38702506
# the predicition is:  (array([1], dtype=int64),)  ->  0.23161401
# the predicition is:  (array([3], dtype=int64),)  ->  0.9970542
# the predicition is:  (array([16], dtype=int64),)  ->  0.9846955
# the predicition is:  (array([8], dtype=int64),)  ->  0.96059644
# the predicition is:  (array([3], dtype=int64),)  ->  0.99391264
# the predicition is:  (array([3], dtype=int64),)  ->  0.9760232
# the predicition is:  (array([3], dtype=int64),)  ->  0.7239502
# the predicition is:  (array([3], dtype=int64),)  ->  0.99991167
# the predicition is:  (array([3], dtype=int64),)  ->  0.9929698
# the predicition is:  (array([3], dtype=int64),)  ->  0.5001864
# the predicition is:  (array([1], dtype=int64),)  ->  0.54627043

# %%
#several tests here

model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))
model.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])
model.fit(partial_x_train,
partial_y_train,
epochs=9,
batch_size=512,
validation_data=(x_val, y_val))
results = model.evaluate(x_test, one_hot_test_labels)
results
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 2s 228us/step - loss: 2.6412 - acc: 0.5019 - val_loss: 1.6706 - val_acc: 0.6530
# Epoch 2/9
# 7982/7982 [==============================] - 1s 158us/step - loss: 1.4015 - acc: 0.6984 - val_loss: 1.2905 - val_acc: 0.7050
# Epoch 3/9
# 7982/7982 [==============================] - 1s 153us/step - loss: 1.0598 - acc: 0.7731 - val_loss: 1.1431 - val_acc: 0.7540
# Epoch 4/9
# 7982/7982 [==============================] - 1s 154us/step - loss: 0.8424 - acc: 0.8172 - val_loss: 1.0903 - val_acc: 0.7620
# Epoch 5/9
# 7982/7982 [==============================] - 1s 154us/step - loss: 0.6792 - acc: 0.8495 - val_loss: 1.0825 - val_acc: 0.7800
# Epoch 6/9
# 7982/7982 [==============================] - 1s 157us/step - loss: 0.5443 - acc: 0.8832 - val_loss: 0.9801 - val_acc: 0.8110
# Epoch 7/9
# 7982/7982 [==============================] - 1s 155us/step - loss: 0.4289 - acc: 0.9085 - val_loss: 1.0296 - val_acc: 0.7840
# Epoch 8/9
# 7982/7982 [==============================] - 1s 155us/step - loss: 0.3621 - acc: 0.9232 - val_loss: 0.9831 - val_acc: 0.8180
# Epoch 9/9
# 7982/7982 [==============================] - 1s 157us/step - loss: 0.2901 - acc: 0.9380 - val_loss: 1.0123 - val_acc: 0.8090
# 2246/2246 [==============================] - 0s 157us/step
# [1.0774509915261001, 0.7764915405164737]
